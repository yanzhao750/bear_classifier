# %%
# Install and import packages
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila

from fastai.vision.all import *
from fastai.vision.widgets import*
from pathlib import Path
# Out:
# ...
# Enabling: voila
# - Writing config: /usr/etc/jupyter
#     - Validating...
#       voila 0.5.2 OK

# %%
# Define path
path = Path()

# %%
# Load learner
learn = load_learner(path/'model.pkl')

# %%
# Create widgets to display and label image
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
# Create upload button
btn_upload = widgets.FileUpload()

# Create classify button
btn_classify = widgets.Button(description='Classify')

# Define click event handler for classify button
def on_click_classify(change):
  img = PILImage.create(btn_upload.data[-1])
  out_pl.clear_output()
  with out_pl: display(img.to_thumb(128,128))
  pred, pred_idx, probs = learn.predict(img)
  lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_classify.on_click(on_click_classify)

# %%
# Create GUI Vbox
VBox([widgets.Label('Upload a bear image to classify! Supported types are black, grizzly, and teddy.'),
      btn_upload, btn_classify, out_pl, lbl_pred])
